# %%
# !pip install nltk==3.8.1 --upgrade
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 18.6 MB/s  0:00:00
# ...
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.9.1
#     Uninstalling nltk-3.9.1:
#       Successfully uninstalled nltk-3.9.1
# ...

# %%
import pandas as pd
import nltk
nltk.download('punkt')
import warnings
import plotly.express as px
import numpy as np
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/isabellventouris/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from nltk.tokenize import word_tokenize

print(word_tokenize("This is a test sentence."))
# Out:
# ['This', 'is', 'a', 'test', 'sentence', '.']

# %%
df_Obama_speech = pd.read_csv('Text 1-Obama speech.csv',encoding='cp1252')
df_Trump_speech = pd.read_csv('Text 1-Trump speech.csv',encoding='cp1252')

# %%
df_Obama_2013 = pd.read_csv('2013-Obama.txt', on_bad_lines='skip',encoding='utf8')

# %%
df_Obama_2014 = pd.read_csv('2014-Obama.txt', on_bad_lines='skip',encoding='utf8')

# %%
df_Obama_2015 = pd.read_csv('2015-Obama.txt', on_bad_lines='skip',encoding='utf8')

# %%
df_Clinton_1997 = pd.read_csv('1997-Clinton.txt', on_bad_lines='skip',encoding='utf8')

# %%
df_presidents_sheet = pd.read_csv('Text 5-adverbs-sous-presidents-Sheet1.csv',encoding='cp1252')

# %%
df_Obama_Sous = pd.read_csv('Text 4-sous-2012-Obama.txt', on_bad_lines='skip',encoding='utf8')

# %%
df_SUBTLEX_PoS = pd.read_csv('Text 5-SUBTLEX_PoS.csv',encoding='cp1252')

# %%
df_GWBush_2001 = pd.read_csv('2001-GWBush-1.txt', on_bad_lines='skip',encoding='utf8')

# %%
df_sou_texts = pd.read_csv('Text 5-adverbs-sous-texts.csv',on_bad_lines='skip',encoding='utf8')

# %%
df_Obama_2016 = pd.read_csv('2016-Obama.txt', on_bad_lines='skip',encoding='cp1252')

# %%
df_Obama_Inaug = pd.read_csv('Obama2009.txt', on_bad_lines='skip',encoding='cp1252')
df_Obama_Inaug
# Out:
#                                                      I stand here today humbled by the task before us  \
# Forty-four Americans have now taken the preside...   every so often the oath is taken amidst gathe...
# So it has been. So it must be with this generat...                                                NaN
# That we are in the midst of crisis is now well ...   against a far-reaching network of violence an...
# These are the indicators of crisis                   subject to data and statistics. Less measurab...
# Today I say to you that the challenges we face ...                          AmericaÑthey will be met.
# On this day                                           we gather because we have chosen hope over fear
# On this day                                          we come to proclaim an end to the petty griev...
# For us                                               they packed up their few worldly possessions ...
# ...

# %%
df_Obama_Inaug = df_Obama_Inaug[df_Obama_Inaug.columns[1:]].apply(
    lambda x: ','.join(x.dropna().astype(str)),
    axis=1
)
df_Obama_Inaug
# Out:
# Forty-four Americans have now taken the presidential oath. The words have been spoken during rising tides of prosperity and the still waters of peace. Yet                                                                                                                     America has carried on not simply because of ...
# So it has been. So it must be with this generation of Americans.
# That we are in the midst of crisis is now well understood. Our nation is at war                                                                                                                                                                                                a consequence of greed and irresponsibility o...
# ...

# %%
df_Trump_Inaug = pd.read_csv('Text 3-Trump Inaug.2017.txt', on_bad_lines='skip',encoding='utf8')
df_Trump_Inaug
# Out:
#                                 Chief Justice Roberts  \
# 0                                                  We
# 1                                            Together
# 2   We will face challenges. We will confront hard...
# 3                                    Every four years
# 4                                    Today’s ceremony
# ..                                                ...
# 69                                           Together
# 70                We Will Make America Wealthy Again.
# 71                  We Will Make America Proud Again.
# 72                   We Will Make America Safe Again.
# 73                                                And
#
#                                      President Carter  \
# 0                             the citizens of America
# 1    we will determine the course of America and t...
# 2                                                 NaN
# 3    we gather on these steps to carry out the ord...
# ...

# %%
df_Trump_Inaug = df_Trump_Inaug[df_Trump_Inaug.columns[1:]].apply(
    lambda x: ','.join(x.dropna().astype(str)),
    axis=1
)
df_Trump_Inaug
# Out:
# 0      the citizens of America, are now joined in a ...
# 1      we will determine the course of America and t...
# 2
# 3      we gather on these steps to carry out the ord...
# 4      however, has very special meaning. Because to...
#                             ...
# 69                   We Will Make America Strong Again.
# 70
# 71
# 72
# 73     Yes, Together, We Will Make America Great Aga...
# Length: 74, dtype: object

# %%
df_GWBush_Inaug = pd.read_csv('GWBush-Inaug-2001.txt', on_bad_lines='skip',encoding='utf8')
df_GWBush_Inaug
# Out:
#                                     President Clinton  \
# 0                                          As I begin
# 1   And I thank Vice President Gore for a contest ...
# 2              I am honored and humbled to stand here
# 3   It is the American story—a story of flawed and...
# 4   The grandest of these ideals is an unfolding A...
# 5   Americans are called to enact this promise in ...
# 6                    Through much of the last century
# 7   Our democratic faith is more than the creed of...
# 8                               We do not accept this
# 9   I know this is in our reach because we are gui...
# 10  And we are confident in principles that unite ...
# 11                                              Today
# 12                                            America
# 13  Some seem to believe that our politics can aff...
# 14  But the stakes for America are never small. If...
# 15  We must live up to the calling we share. Civil...
# ...

# %%
df_GWBush_Inaug = df_GWBush_Inaug[df_GWBush_Inaug.columns[1:]].apply(
    lambda x: ','.join(x.dropna().astype(str)),
    axis=1
)
df_GWBush_Inaug
# Out:
# 0      I thank President Clinton for his service to ...
# 1
# 2      where so many of America's leaders have come ...
# 3      united across the generations by grand and en...
# 4      that everyone deserves a chance, that no insi...
# 5      and sometimes delayed, we must follow no othe...
# 6      America's faith in freedom and democracy was ...
# 7      it is the inborn hope of our humanity, an ide...
# 8      and we will not allow it. Our unity, our unio...
# 9
# 10
# 11     we affirm a new commitment to live out our na...
# 12     at its best, matches a commitment to principl...
# 13     in a time of peace, the stakes of our debates...
# 14     it will not be led. If we do not turn the hea...
# 15     of community over chaos. And this commitment,...
# 16                     at its best, is also courageous.
# 17     when defending common dangers defined our com...
# 18     we will reclaim America's schools, before ign...
# 19     sparing our children from struggles we have t...
# ...

# %%
df_Clinton_Inaug = pd.read_csv('Clinton_Inaug_1993.txt', on_bad_lines='skip',encoding='utf8')
df_Clinton_Inaug
# Out:
#                                    My fellow citizens  \
# 0                             On behalf of our Nation
# 1                                               Today
# 2   When George Washington first took the oath I h...
# 3   We earn our livelihood in America today in pea...
# 4   Our democracy must be not only the envy of the...
# 5                                    To renew America
# 6   Our Founders saw themselves in the light of po...
# 7                                    To renew America
# 8                                    To renew America
# 9   The American people have summoned the change w...
# 10                                My fellow Americans
# 11  Today we do more than celebrate America. We re...
# 12                                             And so
# 13                                          Thank you
#
#     today we celebrate the mystery of American renewal. This ceremony is held in the depth of winter  \
# ...

# %%
df_Clinton_Inaug = df_Clinton_Inaug[df_Clinton_Inaug.columns[1:]].apply(
    lambda x: ','.join(x.dropna().astype(str)),
    axis=1
)
df_Clinton_Inaug
# Out:
# 0      I salute my predecessor, President Bush, for ...
# 1      a generation raised in the shadows of the col...
# 2      news traveled slowly across the land by horse...
# 3      great and small; when the fear of crime robs ...
# 4       and a new season of American renewal has begun.
# 5      we must be bold. We must do what no generatio...
# 6      from whom we have borrowed our planet, and to...
# 7      we must revitalize our democracy. This beauti...
# 8      we must meet challenges abroad as well as at ...
# 9      the Presidency, and the political process its...
# 10     you, too, must play your part in our renewal....
# 11     an idea born in revolution and renewed throug...
# 12     my fellow Americans, as we stand at the edge ...
# 13                               and God bless you all.
# dtype: object

# %% [markdown]
# Turn words into bag of words

# %%
from sklearn.feature_extraction.text import CountVectorizer

# create the vocabulary
vectorizer_clinton = CountVectorizer()

# fit the vocabulary to the text data
vectorizer_clinton.fit(df_Clinton_Inaug)

# create the bag-of-words model
bow_model_Clinton = vectorizer_clinton.transform(df_Clinton_Inaug)

# %%
print(bow_model_Clinton)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 638 stored elements and shape (14, 404)>
#   Coords	Values
#   (0, 13)	1
#   (0, 19)	4
#   (0, 54)	1
#   (0, 68)	1
#   (0, 85)	1
#   (0, 104)	1
#   (0, 137)	1
#   (0, 142)	1
#   (0, 165)	1
#   (0, 175)	1
#   (0, 221)	1
#   (0, 223)	1
#   (0, 230)	1
#   (0, 241)	2
#   (0, 258)	1
#   (0, 277)	1
#   (0, 279)	1
#   (0, 304)	1
#   (0, 306)	1
#   (0, 314)	1
#   (0, 332)	1
#   (0, 341)	1
#   (0, 343)	1
#   (0, 354)	1
#   (0, 361)	1
#   :	:
#   (12, 289)	1
#   (12, 309)	1
#   (12, 310)	1
#   (12, 311)	1
#   (12, 314)	1
#   (12, 317)	1
#   (12, 331)	1
#   (12, 343)	7
#   (12, 349)	1
#   (12, 354)	1
#   (12, 363)	1
#   (12, 372)	1
#   (12, 375)	3
#   (12, 376)	1
#   (12, 382)	1
#   (12, 383)	7
#   (12, 385)	1
#   (12, 386)	1
#   (12, 394)	3
#   (12, 396)	2
#   (13, 9)	1
#   (13, 19)	1
#   (13, 47)	1
#   (13, 159)	1
#   (13, 401)	1

# %%
from sklearn.feature_extraction.text import CountVectorizer

# create the vocabulary
vectorizer_bush = CountVectorizer()

# fit the vocabulary to the text data
vectorizer_bush.fit(df_GWBush_Inaug)

# create the bag-of-words model
bow_model_Bush = vectorizer_bush.transform(df_GWBush_Inaug)

# %%
print(bow_model_Bush)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 692 stored elements and shape (44, 378)>
#   Coords	Values
#   (0, 74)	1
#   (0, 135)	1
#   (0, 157)	1
#   (0, 214)	1
#   (0, 234)	1
#   (0, 253)	1
#   (0, 286)	1
#   (0, 320)	1
#   (0, 336)	1
#   (2, 17)	1
#   (2, 21)	1
#   (2, 39)	1
#   (2, 75)	1
#   (2, 134)	1
#   (2, 155)	1
#   (2, 191)	1
#   (2, 202)	2
#   (2, 204)	1
#   (2, 225)	1
#   (2, 294)	2
#   (2, 361)	1
#   (2, 365)	1
#   (3, 5)	1
#   (3, 21)	1
#   (3, 55)	1
#   :	:
#   (39, 372)	1
#   (39, 375)	1
#   (41, 4)	1
#   (41, 21)	2
#   (41, 23)	1
#   (41, 111)	2
#   (41, 117)	1
#   (41, 132)	1
#   (41, 140)	1
#   (41, 157)	2
#   (41, 172)	2
#   (41, 180)	2
#   (41, 227)	1
#   (41, 234)	2
#   (41, 261)	2
#   (41, 286)	1
#   (41, 334)	1
#   (41, 336)	1
#   (41, 364)	1
#   (41, 367)	1
#   (41, 374)	1
#   (43, 17)	1
#   (43, 21)	1
#   (43, 46)	1
#   (43, 149)	1

# %%
from sklearn.feature_extraction.text import CountVectorizer

# create the vocabulary
vectorizer_obama = CountVectorizer()

# fit the vocabulary to the text data
vectorizer_obama.fit(df_Obama_Inaug)

# create the bag-of-words model
bow_model_Obama = vectorizer_bush.transform(df_Obama_Inaug)

# %%
print(bow_model_Obama)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 132 stored elements and shape (21, 378)>
#   Coords	Values
#   (0, 17)	1
#   (0, 21)	1
#   (0, 38)	2
#   (0, 54)	1
#   (0, 155)	1
#   (0, 168)	1
#   (0, 172)	1
#   (0, 223)	1
#   (0, 225)	3
#   (0, 226)	1
#   (0, 231)	1
#   (0, 234)	2
#   (0, 322)	3
#   (0, 331)	1
#   (0, 336)	2
#   (0, 357)	1
#   (2, 16)	1
#   (2, 21)	4
#   (2, 51)	1
#   (2, 54)	1
#   (2, 59)	1
#   (2, 91)	1
#   (2, 112)	1
#   (2, 135)	1
#   (2, 155)	1
#   :	:
#   (14, 321)	1
#   (14, 322)	2
#   (14, 323)	2
#   (14, 333)	1
#   (14, 336)	2
#   (14, 350)	1
#   (14, 362)	1
#   (14, 364)	1
#   (14, 367)	1
#   (18, 20)	1
#   (18, 31)	1
#   (18, 36)	1
#   (18, 55)	1
#   (18, 172)	2
#   (18, 210)	1
#   (18, 214)	1
#   (18, 225)	5
#   (18, 226)	1
#   (18, 234)	2
#   (18, 293)	1
#   (18, 322)	8
#   (18, 336)	1
#   (18, 355)	4
#   (18, 360)	1
#   (18, 367)	1

# %%
from sklearn.feature_extraction.text import CountVectorizer

# create the vocabulary
vectorizer_trump = CountVectorizer()

# fit the vocabulary to the text data
vectorizer_trump.fit(df_Trump_Inaug)

# create the bag-of-words model
bow_model_Trump = vectorizer_trump.transform(df_Trump_Inaug)

# %%
print(bow_model_Trump)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 562 stored elements and shape (74, 318)>
#   Coords	Values
#   (0, 7)	1
#   (0, 11)	1
#   (0, 14)	1
#   (0, 16)	1
#   (0, 45)	1
#   (0, 54)	1
#   (0, 78)	1
#   (0, 99)	1
#   (0, 117)	1
#   (0, 136)	1
#   (0, 143)	1
#   (0, 145)	1
#   (0, 183)	1
#   (0, 191)	1
#   (0, 194)	2
#   (0, 201)	2
#   (0, 207)	1
#   (0, 214)	1
#   (0, 224)	1
#   (0, 228)	1
#   (0, 263)	1
#   (0, 274)	2
#   (1, 11)	1
#   (1, 14)	1
#   (1, 48)	1
#   :	:
#   (68, 201)	1
#   (68, 263)	1
#   (68, 294)	1
#   (68, 300)	1
#   (68, 306)	2
#   (68, 317)	3
#   (69, 4)	1
#   (69, 11)	1
#   (69, 168)	1
#   (69, 255)	1
#   (69, 301)	1
#   (69, 306)	1
#   (73, 4)	1
#   (73, 11)	2
#   (73, 14)	1
#   (73, 32)	2
#   (73, 109)	2
#   (73, 117)	1
#   (73, 168)	1
#   (73, 261)	1
#   (73, 276)	1
#   (73, 301)	1
#   (73, 306)	1
#   (73, 314)	1
#   (73, 315)	2

# %% [markdown]
# Preprocess

# %%
import nltk
import string
import re 
  
def WordPreProcessing(text_data):

    # create the vocabulary
    vocab = set()

    # create the bag-of-words model
    bow_model = []

    for text in text_data:
        #print("text : " + text)
        # create a dictionary to store the word counts
        word_counts = {}

        # remove leading and trailing white space
        text = text.strip()

        # replace multiple consecutive white space characters with a single space
        text = " ".join(text.split())

        #print("remove spaces : "+text)
        # tokenize the text
        tokens = nltk.word_tokenize(text)
        #print (tokens)
        # lowercase the tokens
        lowercased_tokens = [token.lower() for token in tokens]

        #print("lower Case : " + str (lowercased_tokens))
        # remove punctuation
        filtered_tokens = [token for token in lowercased_tokens if token not in string.punctuation]

        #print("filtered_punct :" + str (filtered_tokens))
        # get list of stopwords in English
        stopwords = nltk.corpus.stopwords.words("english")

        # remove stopwords
        filtered_tokens = [token for token in filtered_tokens if token not in stopwords]

        # remove non english charcter in words
        filtered_tokens = [re.sub(r'[^a-zA-Z0-9\s]+','',token) for token in filtered_tokens]


        #print("filtered_stopwords :" + str (filtered_tokens))
        # create stemmer object
        stemmer = nltk.stem.PorterStemmer()

        # stem each token
        stemmed_tokens = [stemmer.stem(token) for token in filtered_tokens]

        # remove empty words
        last_stage = [token for token in stemmed_tokens if token]

        #print("stemmed_tokens :" + str (stemmed_tokens))
        # update the vocabulary
        vocab.update(last_stage)

        # count the occurrences of each word
        for word in last_stage:
            if word in word_counts:
                word_counts[word] += 1
            else:
                word_counts[word] = 1

        # add the word counts to the bag-of-words model
        bow_model.append(word_counts)
    return bow_model

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/isabellventouris/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
text_data = df_Clinton_Inaug
Clinton_Speech_BOW = WordPreProcessing(text_data)

# %%
text_data = df_GWBush_Inaug
Bush_Speech_BOW = WordPreProcessing(text_data)

# %%
text_data = df_Obama_Inaug
Obama_Speech_BOW = WordPreProcessing(text_data)

# %%
text_data = df_Trump_Inaug
Trump_Speech_BOW = WordPreProcessing(text_data)

# %%
len(Trump_Speech_BOW)
# Out:
# 74

# %%
len(Clinton_Speech_BOW)
# Out:
# 14

# %%
len(Obama_Speech_BOW)
# Out:
# 21

# %%
len(Bush_Speech_BOW)
# Out:
# 44

# %% [markdown]
# Generate Word Frequencies and comapre between Different BOW (Bag of words)

# %%
def display_Frequencies(speech):
    words = []
    count = []
    for i in range(len(speech)):
        for keys in speech[i].keys():
            words.append(keys)
        for values in speech[i].values():
            count.append(values)
    fig = px.bar(x=words, y=count)
    fig.show()

# %%
display_Frequencies(Clinton_Speech_BOW)

# %%
display_Frequencies(Bush_Speech_BOW)

# %%
display_Frequencies(Obama_Speech_BOW)

# %%
display_Frequencies(Trump_Speech_BOW)

# %%
def Return_df(speech):
    words = []
    count = []
    for i in range(len(speech)):
        for keys in speech[i].keys():
            words.append(keys)
        for values in speech[i].values():
            count.append(values)
    return pd.DataFrame({"words":words,"variable Count":count})

# %%
# Transform bag of words into data frame
Clinton_speech_df = Return_df(Clinton_Speech_BOW)
Bush_speech_df = Return_df(Bush_Speech_BOW)
Obama_speech_df = Return_df(Obama_Speech_BOW)
Trump_speech_df = Return_df(Trump_Speech_BOW)

# %%
TopTenC = Clinton_speech_df.sort_values(['variable Count'], ascending=False).iloc[:15,]
TopTenC = TopTenC.reset_index(drop=True)
TopTenC = TopTenC.rename(columns={"words": "Clinton", "variable Count": "Count"})
TopTenB = Bush_speech_df.sort_values(['variable Count'], ascending=False).iloc[:15,]
TopTenB = TopTenB.reset_index(drop=True)
TopTenB = TopTenB.rename(columns={"words": "Bush", "variable Count": "Count"})
TopTenO = Obama_speech_df.sort_values(['variable Count'], ascending=False).iloc[:15,]
TopTenO = TopTenO.reset_index(drop=True)
TopTenO = TopTenO.rename(columns={"words": "Obama", "variable Count": "Count"})
TopTenT = Trump_speech_df.sort_values(['variable Count'], ascending=False).iloc[:15,]
TopTenT = TopTenT.reset_index(drop=True)
TopTenT = TopTenT.rename(columns={"words": "Trump", "variable Count": "Count"})

# %%
result = pd.concat([TopTenC, TopTenB, TopTenO, TopTenT], axis=1)
result
# Out:
#     Clinton  Count     Bush  Count     Obama  Count     Trump  Count
# 0     world      6  citizen      4   prosper      3     bless      2
# 1      must      6       us      2     world      2  american      2
# 2        us      5   spirit      2         s      2     ocean      2
# 3     peopl      5      new      2       see      2  industri      2
# 4       let      4     work      2      hour      2     obama      2
# 5      idea      4    civil      2     chang      2    moment      2
# 6     capit      3   common      2  selfless      1      left      2
# 7        us      3   purpos      2         s      1       one      2
# 8       let      3     find      2   resourc      1  transfer      2
# 9   respons      3     must      2   without      1     power      2
# 10    still      2     duti      2    regard      1       one      2
# 11     work      2   nation      2    effect      1   million      2
# 12    power      2     mani      2      must      1   loyalti      2
# ...

# %% [markdown]
# Cosine similarity

# %%
# %pip install spacy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 66.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 74.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 634.4/634.4 kB 26.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 845.3/845.3 kB 45.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 52.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 76.4 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28/28 [spacy]m27/28 [spacy]ge-data]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import spacy
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
import nltk
import spacy
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# Cosine similarity

# %%
W = pd.read_csv('Clinton_Inaug_1993.txt', on_bad_lines='skip',encoding='utf8')
W = W[W.columns[1:]].apply(
    lambda x: ','.join(x.dropna().astype(str)),
    axis=1
)
W = W.to_string().lower()
W
# Out:
# '0      i salute my predecessor, president bush, for ...\n1      a generation raised in the shadows of the col...\n2      news traveled slowly across the land by horse...\n3      great and small; when the fear of crime robs ...\n4       and a new season of american renewal has begun.\n5      we must be bold. we must do what no generatio...\n6      from whom we have borrowed our planet, and to...\n7      we must revitalize our democracy. this beauti...\n8      we must meet challenges abroad as well as at ...\n9      the presidency, and the political process its...\n10     you, too, must play your part in our renewal....\n11     an idea born in revolution and renewed throug...\n12     my fellow americans, as we stand at the edge ...\n13                               and god bless you all.'

# %%
X = pd.read_csv('GWBush-Inaug-2001.txt', on_bad_lines='skip',encoding='utf8')
X = X[X.columns[1:]].apply(
    lambda x: ','.join(x.dropna().astype(str)),
    axis=1
)
X = X.to_string().lower()
X
# Out:
# "0      i thank president clinton for his service to ...\n1                                                      \n2      where so many of america's leaders have come ...\n3      united across the generations by grand and en...\n4      that everyone deserves a chance, that no insi...\n5      and sometimes delayed, we must follow no othe...\n6      america's faith in freedom and democracy was ...\n7      it is the inborn hope of our humanity, an ide...\n8      and we will not allow it. our unity, our unio...\n9                                                      \n10                                                     \n11     we affirm a new commitment to live out our na...\n12     at its best, matches a commitment to principl...\n13     in a time of peace, the stakes of our debates...\n14     it will not be led. if we do not turn the hea...\n15     of community over chaos. and this commitment,...\n16                     at its best, is also courageous.\n17     when defending common
# ...

# %%
Y = pd.read_csv('Obama2009.txt', on_bad_lines='skip',encoding='cp1252')
Y = Y[Y.columns[1:]].apply(
    lambda x: ','.join(x.dropna().astype(str)),
    axis=1
)
Y = Y.to_string().lower()
Y
# Out:
# 'forty-four americans have now taken the presidential oath. the words have been spoken during rising tides of prosperity and the still waters of peace. yet                                                                                                                     america has carried on not simply because of ...\nso it has been. so it must be with this generation of americans.                                                                                                                                                                                                                                                               \nthat we are in the midst of crisis is now well understood. our nation is at war                                                                                                                                                                                                a consequence of greed and irresponsibility o...\nthese are the indicators of crisis
# ...

# %%
Z = pd.read_csv('Text 3-Trump Inaug.2017.txt', on_bad_lines='skip',encoding='utf8')
Z = Z[Z.columns[1:]].apply(
    lambda x: ','.join(x.dropna().astype(str)),
    axis=1
)
Z = Z.to_string().lower()
Z
# Out:
# '0      the citizens of america, are now joined in a ...\n1      we will determine the course of america and t...\n2                                                      \n3      we gather on these steps to carry out the ord...\n4      however, has very special meaning. because to...\n5      a small group in our nation’s capital has rea...\n6                                                      \n7                             and the factories closed.\n8                  but not the citizens of our country.\n9      there was little to celebrate for struggling ...\n10     and right now, because this moment is your mo...\n11                                                     \n12                                                     \n13       the united states of america, is your country.\n14     but whether our government is controlled by t...\n15     will be remembered as the day the people beca...\n16                                                     \n17                          
# ...

# %%
# Program to measure the similarity between  
# two sentences using cosine similarity. 
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize

# %%
# Clinton vs Bush
# tokenization 
W_list = word_tokenize(W)  
X_list = word_tokenize(X) 
  
# sw contains the list of stopwords 
sw = stopwords.words('english')  
l1 =[];l2 =[] 
  
# remove stop words from the string 
W_set = {w for w in W_list if not w in sw}  
X_set = {w for w in X_list if not w in sw} 
  
# form a set containing keywords of both strings  
rvector = W_set.union(X_set)  
for w in rvector: 
    if w in W_set: l1.append(1) # create a vector 
    else: l1.append(0) 
    if w in X_set: l2.append(1) 
    else: l2.append(0) 
c = 0
  
# cosine formula  
for i in range(len(rvector)): 
        c+= l1[i]*l2[i] 
cosine = c / float((sum(l1)*sum(l2))**0.5) 
print("similarity: ", cosine)
# Out:
# similarity:  0.23495144355142164

# %%
# Bush vs Obama
# tokenization 
X_list = word_tokenize(X)  
Y_list = word_tokenize(Y) 
  
# sw contains the list of stopwords 
sw = stopwords.words('english')  
l1 =[];l2 =[] 
  
# remove stop words from the string 
X_set = {w for w in X_list if not w in sw}  
Y_set = {w for w in Y_list if not w in sw} 
  
# form a set containing keywords of both strings  
rvector = X_set.union(Y_set)  
for w in rvector: 
    if w in X_set: l1.append(1) # create a vector 
    else: l1.append(0) 
    if w in Y_set: l2.append(1) 
    else: l2.append(0) 
c = 0
  
# cosine formula  
for i in range(len(rvector)): 
        c+= l1[i]*l2[i] 
cosine = c / float((sum(l1)*sum(l2))**0.5) 
print("similarity: ", cosine)
# Out:
# similarity:  0.15839698777049716

# %%
# Obama vs Trump
# tokenization 
Y_list = word_tokenize(Y)  
Z_list = word_tokenize(Z) 
  
# sw contains the list of stopwords 
sw = stopwords.words('english')  
l1 =[];l2 =[] 
  
# remove stop words from the string 
Y_set = {w for w in Y_list if not w in sw}  
Z_set = {w for w in Z_list if not w in sw} 
  
# form a set containing keywords of both strings  
rvector = Y_set.union(Z_set)  
for w in rvector: 
    if w in Y_set: l1.append(1) # create a vector 
    else: l1.append(0) 
    if w in Z_set: l2.append(1) 
    else: l2.append(0) 
c = 0
  
# cosine formula  
for i in range(len(rvector)): 
        c+= l1[i]*l2[i] 
cosine = c / float((sum(l1)*sum(l2))**0.5) 
print("similarity: ", cosine)
# Out:
# similarity:  0.13003912165257484

# %%
# Obama vs Clinton
# tokenization 
Y_list = word_tokenize(Y)  
W_list = word_tokenize(W) 
  
# sw contains the list of stopwords 
sw = stopwords.words('english')  
l1 =[];l2 =[] 
  
# remove stop words from the string 
Y_set = {w for w in Y_list if not w in sw}  
W_set = {w for w in W_list if not w in sw} 
  
# form a set containing keywords of both strings  
rvector = Y_set.union(W_set)  
for w in rvector: 
    if w in Y_set: l1.append(1) # create a vector 
    else: l1.append(0) 
    if w in W_set: l2.append(1) 
    else: l2.append(0) 
c = 0
  
# cosine formula  
for i in range(len(rvector)): 
        c+= l1[i]*l2[i] 
cosine = c / float((sum(l1)*sum(l2))**0.5) 
print("similarity: ", cosine)
# Out:
# similarity:  0.12818706987301454

# %%
# Clinton vs Trump
# tokenization 
W_list = word_tokenize(W)  
Z_list = word_tokenize(Z) 
  
# sw contains the list of stopwords 
sw = stopwords.words('english')  
l1 =[];l2 =[] 
  
# remove stop words from the string 
W_set = {w for w in W_list if not w in sw}  
Z_set = {w for w in Z_list if not w in sw} 
  
# form a set containing keywords of both strings  
rvector = W_set.union(Z_set)  
for w in rvector: 
    if w in W_set: l1.append(1) # create a vector 
    else: l1.append(0) 
    if w in Z_set: l2.append(1) 
    else: l2.append(0) 
c = 0
  
# cosine formula  
for i in range(len(rvector)): 
        c+= l1[i]*l2[i] 
cosine = c / float((sum(l1)*sum(l2))**0.5) 
print("similarity: ", cosine)
# Out:
# similarity:  0.1840294470674847

# %%
# Bush vs Trump
# tokenization 
X_list = word_tokenize(X)  
Z_list = word_tokenize(Z) 
  
# sw contains the list of stopwords 
sw = stopwords.words('english')  
l1 =[];l2 =[] 
  
# remove stop words from the string 
X_set = {w for w in X_list if not w in sw}  
Z_set = {w for w in Z_list if not w in sw} 
  
# form a set containing keywords of both strings  
rvector = X_set.union(Z_set)  
for w in rvector: 
    if w in X_set: l1.append(1) # create a vector 
    else: l1.append(0) 
    if w in Z_set: l2.append(1) 
    else: l2.append(0) 
c = 0
  
# cosine formula  
for i in range(len(rvector)): 
        c+= l1[i]*l2[i] 
cosine = c / float((sum(l1)*sum(l2))**0.5) 
print("similarity: ", cosine)
# Out:
# similarity:  0.2867214478562801

# %% [markdown]
# Sentiment Analysis

# %%
import pandas as pd
import numpy as np
import nltk
import matplotlib.pyplot as plt
# %matplotlib inline
#import statsmodels.api as sm
#import statsmodels.formula.api as smf
import scipy as sp
import os
import re
from nltk.corpus import stopwords

# %%
files = ["Clinton_Inaug_1993.txt", "GWBush-Inaug-2001.txt", "Obama2009.txt", "Text 3-Trump Inaug.2017.txt"]

# read lines command

corpus = []
for d in files: 
    with open( str(d), encoding = 'latin1') as nf:
        lines = nf.readlines()
    
    i = 1
    for x in lines: 
        words = x.split()
        for w in words:
            corpus.append([d, i, w])
                
        i += 1
    
    #file_path = '/Downloads/'+ str(d) 
    #paper_words = pd.DataFrame({'file': [d for d in file_path]})
    #paper_words['text'] = paper_words['file'].apply(lambda x: open(x).read().splitlines())
corpus
# Out:
# [['Clinton_Inaug_1993.txt', 1, 'My'],
#  ['Clinton_Inaug_1993.txt', 1, 'fellow'],
#  ['Clinton_Inaug_1993.txt', 1, 'citizens,'],
#  ['Clinton_Inaug_1993.txt', 1, 'today'],
#  ['Clinton_Inaug_1993.txt', 1, 'we'],
#  ['Clinton_Inaug_1993.txt', 1, 'celebrate'],
#  ['Clinton_Inaug_1993.txt', 1, 'the'],
#  ['Clinton_Inaug_1993.txt', 1, 'mystery'],
#  ['Clinton_Inaug_1993.txt', 1, 'of'],
#  ['Clinton_Inaug_1993.txt', 1, 'American'],
#  ['Clinton_Inaug_1993.txt', 1, 'renewal.'],
#  ['Clinton_Inaug_1993.txt', 1, 'This'],
#  ['Clinton_Inaug_1993.txt', 1, 'ceremony'],
#  ['Clinton_Inaug_1993.txt', 1, 'is'],
#  ['Clinton_Inaug_1993.txt', 1, 'held'],
#  ['Clinton_Inaug_1993.txt', 1, 'in'],
#  ['Clinton_Inaug_1993.txt', 1, 'the'],
#  ['Clinton_Inaug_1993.txt', 1, 'depth'],
#  ['Clinton_Inaug_1993.txt', 1, 'of'],
#  ['Clinton_Inaug_1993.txt', 1, 'winter,'],
#  ['Clinton_Inaug_1993.txt', 1, 'but'],
#  ['Clinton_Inaug_1993.txt', 1, 'by'],
#  ['Clinton_Inaug_1993.txt', 1, 'the'],
# ...

# %%
stop_words = list(stopwords.words('english'))
stop_words
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
for word in corpus: # iterate over word_list
  if word[2] in stop_words: 
    corpus.remove(word) # remove word from paperwords if it is a stopword

# %%
len(corpus)
# Out:
# 4676

# %%
Corpus = pd.DataFrame(corpus, columns = ['speech', 'line', 'word'])
Corpus
# Out:
#                            speech  line       word
# 0          Clinton_Inaug_1993.txt     1         My
# 1          Clinton_Inaug_1993.txt     1     fellow
# 2          Clinton_Inaug_1993.txt     1  citizens,
# 3          Clinton_Inaug_1993.txt     1      today
# 4          Clinton_Inaug_1993.txt     1  celebrate
# ...                           ...   ...        ...
# 4671  Text 3-Trump Inaug.2017.txt    75       You,
# 4672  Text 3-Trump Inaug.2017.txt    75        And
# 4673  Text 3-Trump Inaug.2017.txt    75        God
# 4674  Text 3-Trump Inaug.2017.txt    75      Bless
# 4675  Text 3-Trump Inaug.2017.txt    75   America.
#
# [4676 rows x 3 columns]

# %%
Corpus.shape
# Out:
# (4676, 3)

# %%
Corpus["word"] = Corpus['word'].str.replace('[^\w\s]','', regex='True')
Corpus
# Out:
#                            speech  line       word
# 0          Clinton_Inaug_1993.txt     1         My
# 1          Clinton_Inaug_1993.txt     1     fellow
# 2          Clinton_Inaug_1993.txt     1   citizens
# 3          Clinton_Inaug_1993.txt     1      today
# 4          Clinton_Inaug_1993.txt     1  celebrate
# ...                           ...   ...        ...
# 4671  Text 3-Trump Inaug.2017.txt    75        You
# 4672  Text 3-Trump Inaug.2017.txt    75        And
# 4673  Text 3-Trump Inaug.2017.txt    75        God
# 4674  Text 3-Trump Inaug.2017.txt    75      Bless
# 4675  Text 3-Trump Inaug.2017.txt    75    America
#
# [4676 rows x 3 columns]

# %%
# obtaining sentiment list from ntlk module and turning it into a dataframe
df_bing = pd.read_csv('bing.csv')
df_bing.head()
# Out:
#    Unnamed: 0        word sentiment
# 0           1     2-faces  negative
# 1           2    abnormal  negative
# 2           3     abolish  negative
# 3           4  abominable  negative
# 4           5  abominably  negative

# %%
#inner merging on word
result = Corpus.merge(df_bing, on = 'word')
result.head(-5)
# Out:
#                           speech  line       word  Unnamed: 0 sentiment
# 0         Clinton_Inaug_1993.txt     1  celebrate         802  positive
# 1         Clinton_Inaug_1993.txt     1    mystery        4184  negative
# 2         Clinton_Inaug_1993.txt     1    courage        1085  positive
# 3         Clinton_Inaug_1993.txt     1    liberty        3791  positive
# 4         Clinton_Inaug_1993.txt     1  happiness        2822  positive
# ..                           ...   ...        ...         ...       ...
# 538  Text 3-Trump Inaug.2017.txt    66      bleed         562  negative
# 539  Text 3-Trump Inaug.2017.txt    66      enjoy        2014  positive
# 540  Text 3-Trump Inaug.2017.txt    66   glorious        2679  positive
# 541  Text 3-Trump Inaug.2017.txt    66   freedoms        2524  positive
# 542  Text 3-Trump Inaug.2017.txt    66     salute        5215  positive
#
# [543 rows x 5 columns]

# %%
result['sentiment'] = result['sentiment'].replace('positive', 1)
result['sentiment'] = result['sentiment'].replace('negative', -1)
result['percentage'] = round(result['line'] / max(result['line']) *100/5)*5

# %%
c1993 = result[result['speech'] == 'Clinton_Inaug_1993.txt']
b2001 = result.loc[result['speech'] == 'GWBush-Inaug-2001.txt']
o2009 = result.loc[result['speech'] == 'Obama2009.txt']
t2017 = result.loc[result['speech'] == 'Text 3-Trump Inaug.2017.txt']

# %%
c1993a = c1993[['percentage', 'speech', 'sentiment']].groupby('percentage')['sentiment'].sum()
b2001a = b2001[['percentage', 'speech', 'sentiment']].groupby('percentage')['sentiment'].sum()
o2009a = o2009[['percentage', 'speech', 'sentiment']].groupby('percentage')['sentiment'].sum()
t2017a = t2017[['percentage', 'speech', 'sentiment']].groupby('percentage')['sentiment'].sum()

# %%
c1993a
# Out:
# percentage
# 0.0      3
# 5.0      3
# 10.0     1
# 15.0    15
# 20.0    10
# 25.0     5
# Name: sentiment, dtype: int64

# %%
b2001a
# Out:
# percentage
# 0.0      3
# 5.0      6
# 10.0     0
# 15.0     4
# 20.0     4
# 25.0    10
# 30.0     6
# 35.0    -2
# 40.0    -2
# 45.0     0
# 50.0    -1
# 55.0    15
# 60.0     6
# 65.0     8
# 70.0     4
# Name: sentiment, dtype: int64

# %%
o2009a
# Out:
# percentage
# 0.0      5
# 5.0     -9
# 10.0    -5
# 15.0    12
# 20.0     3
# 25.0    17
# 30.0     5
# 35.0     3
# 40.0     9
# 45.0     0
# 50.0     5
# Name: sentiment, dtype: int64

# %%
t2017a
# Out:
# percentage
# 0.0      1
# 5.0      5
# 15.0     3
# 20.0     1
# 30.0     4
# 35.0     2
# 40.0    -1
# 45.0    -1
# 50.0    -1
# 55.0     4
# 60.0     3
# 65.0     5
# 70.0     2
# 75.0     3
# 80.0     0
# 85.0     0
# 90.0     2
# 95.0     7
# 100.0    4
# Name: sentiment, dtype: int64

# %%
from numpy import *
import math
import matplotlib.pyplot as plt

plt.plot(c1993a, 'b', label = 'Clinton')
plt.plot(b2001a, 'r', label = 'Bush') 
plt.plot(o2009a, 'g', label = 'Obama')
plt.plot(t2017a, 'y', label = 'Trump')
plt.xlabel('% Progress Along Speech')
plt.ylabel('Sentiment')



plt.legend()
plt.show()

# %%
pw = Corpus[['speech', 'word']] 
d = pw.groupby(['speech', 'word']).size().reset_index(name='n')

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

# Create a CountVectorizer object and fit it on the documents

vectorizer = CountVectorizer()
dtm = vectorizer.fit_transform(d['word'])

# %%
dtm_df = pd.DataFrame(dtm.todense(),
                      index=d['speech'],
                      columns=vectorizer.get_feature_names_out())
dtm_df
# Out:
#                              2017  20th  21st  225  abandoned  abandonment  \
# speech
# Clinton_Inaug_1993.txt          0     0     1    0          0            0
# Clinton_Inaug_1993.txt          0     0     0    0          0            0
# Clinton_Inaug_1993.txt          0     0     0    0          0            0
# Clinton_Inaug_1993.txt          0     0     0    0          0            0
# Clinton_Inaug_1993.txt          0     0     0    0          0            0
# ...                           ...   ...   ...  ...        ...          ...
# Text 3-Trump Inaug.2017.txt     0     0     0    0          0            0
# Text 3-Trump Inaug.2017.txt     0     0     0    0          0            0
# Text 3-Trump Inaug.2017.txt     0     0     0    0          0            0
# Text 3-Trump Inaug.2017.txt     0     0     0    0          0            0
# Text 3-Trump Inaug.2017.txt     0     0     0    0          0            0
#
# ...

# %%
new_df = dtm_df.groupby(dtm_df.index).sum()
new_df
# Out:
#                              2017  20th  21st  225  abandoned  abandonment  \
# speech
# Clinton_Inaug_1993.txt          0     0     1    0          0            0
# GWBush-Inaug-2001.txt           0     0     0    1          0            1
# Obama2009.txt                   0     0     0    0          1            0
# Text 3-Trump Inaug.2017.txt     1     1     0    0          0            0
#
#                              ability  able  abroad  abuse  ...  years  yes  \
# speech                                                     ...
# Clinton_Inaug_1993.txt             0     1       1      0  ...      0    1
# GWBush-Inaug-2001.txt              0     0       0      1  ...      1    0
# Obama2009.txt                      1     0       0      0  ...      1    1
# Text 3-Trump Inaug.2017.txt        0     0       0      0  ...      1    1
#
#                              yesterdays  yet  yielding  you  young  your  \
# speech
# ...

# %%
new = new_df.transpose()
new.corr()
# Out:
# speech                       Clinton_Inaug_1993.txt  GWBush-Inaug-2001.txt  \
# speech
# Clinton_Inaug_1993.txt                     1.000000               0.076573
# GWBush-Inaug-2001.txt                      0.076573               1.000000
# Obama2009.txt                             -0.013492              -0.055674
# Text 3-Trump Inaug.2017.txt                0.092514               0.022927
#
# speech                       Obama2009.txt  Text 3-Trump Inaug.2017.txt
# speech
# Clinton_Inaug_1993.txt           -0.013492                     0.092514
# GWBush-Inaug-2001.txt            -0.055674                     0.022927
# Obama2009.txt                     1.000000                    -0.043183
# Text 3-Trump Inaug.2017.txt      -0.043183                     1.000000

# %% [markdown]
# WordCloud

# %%
# %pip install wordcloud
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# ?WordCloud
# Out:
# Init signature:
# WordCloud(
#     font_path=None,
#     width=400,
#     height=200,
#     margin=2,
#     ranks_only=None,
#     prefer_horizontal=0.9,
#     mask=None,
#     scale=1,
#     color_func=None,
#     max_words=200,
#     min_font_size=4,
#     stopwords=None,
#     random_state=None,
#     background_color='black',
#     max_font_size=None,
#     font_step=1,
#     mode='RGB',
#     relative_scaling='auto',
#     regexp=None,
#     collocations=True,
#     colormap=None,
#     normalize_plurals=True,
#     contour_width=0,
#     contour_color='black',
#     repeat=False,
#     include_numbers=False,
#     min_word_length=0,
#     collocation_threshold=30,
# )
# Docstring:
# Word cloud object for generating and drawing.
#
# Parameters
# ----------
# font_path : string
#     Font path to the font that will be used (OTF or TTF).
#     Defaults to DroidSansMono path on a Linux machine. If you are on
#     another OS or don't have this font, you need to adjust this path.
#
# ...

# %%
#importing the required packages
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
ps = PorterStemmer()
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
Clinton = np.array(Clinton_Speech_BOW)
Clinton = Clinton.tolist()

#Generating a word cloud
from wordcloud import WordCloud, STOPWORDS
cloud_string = ''
for word_list in Clinton:
    cloud_string = cloud_string + ' ' + (' '.join(word_list))
wordcloud1 = WordCloud(stopwords=STOPWORDS,
                      max_words = 30,
                      background_color='white',
                      width=1200,
                      height=1000).generate(cloud_string)

plt.imshow(wordcloud1)
plt.axis('off')
plt.show()

# %%
Bush = np.array(Bush_Speech_BOW)
Bush = Bush.tolist()

#Generating a word cloud
from wordcloud import WordCloud, STOPWORDS
cloud_string = ''
for word_list in Bush:
    cloud_string = cloud_string + ' ' + (' '.join(word_list))
wordcloud2 = WordCloud(stopwords=STOPWORDS,
                      max_words = 30,
                      background_color='white',
                      width=1200,
                      height=1000).generate(cloud_string)

plt.imshow(wordcloud2)
plt.axis('off')
plt.show()

# %%
Obama = np.array(Obama_Speech_BOW)
Obama = Obama.tolist()

#Generating a word cloud
from wordcloud import WordCloud, STOPWORDS
cloud_string = ''
for word_list in Obama:
    cloud_string = cloud_string + ' ' + (' '.join(word_list))
wordcloud3 = WordCloud(stopwords=STOPWORDS,
                      max_words = 30,
                      background_color='white',
                      width=1200,
                      height=1000).generate(cloud_string)

plt.imshow(wordcloud3)
plt.axis('off')
plt.show()

# %%
Trump = np.array(Trump_Speech_BOW)
Trump = Trump.tolist()

#Generating a word cloud
from wordcloud import WordCloud, STOPWORDS
cloud_string = ''
for word_list in Trump:
    cloud_string = cloud_string + ' ' + (' '.join(word_list))
wordcloud4 = WordCloud(stopwords=STOPWORDS,
                      max_words = 30,
                      background_color='white',
                      width=1200,
                      height=1000).generate(cloud_string)

plt.imshow(wordcloud4)
plt.axis('off')
plt.show()

# %%
wordcloud1.to_file("/Users/isabellventouris/Desktop/Github_Speech/wordcloud_clinton.png")
wordcloud2.to_file("/Users/isabellventouris/Desktop/Github_Speech/wordcloud_bush.png")
wordcloud3.to_file("/Users/isabellventouris/Desktop/Github_Speech/wordcloud_obama.png")
wordcloud4.to_file("/Users/isabellventouris/Desktop/Github_Speech/wordcloud_trump.png")
